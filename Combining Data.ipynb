# %%
import pandas as pd

# %%
jan_df = pd.read_csv('./data/202101-citibike-tripdata.csv', low_memory=False)

# %%
jan_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          2513  2021-01-01 00:00:11.9020  2021-01-01 00:42:05.2260
# 1          2519  2021-01-01 00:00:15.0960  2021-01-01 00:42:14.9780
# 2          1207  2021-01-01 00:00:28.9300  2021-01-01 00:20:36.6510
# 3          2506  2021-01-01 00:00:32.7130  2021-01-01 00:42:19.3980
# 4           959  2021-01-01 00:00:35.3650  2021-01-01 00:16:34.6010
#
#    start station id          start station name  start station latitude  \
# 0              3581  Underhill Ave & Lincoln Pl               40.674012
# 1              3581  Underhill Ave & Lincoln Pl               40.674012
# 2              3144          E 81 St & Park Ave               40.776777
# 3              3581  Underhill Ave & Lincoln Pl               40.674012
# 4               534     Water - Whitehall Plaza               40.702551
#
#    start station longitude  end station id            end station name  \
# ...

# %%
feb_df = pd.read_csv('./data/202102-citibike-tripdata.csv', low_memory=False)

# %%
feb_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           304  2021-02-01 00:04:23.0780  2021-02-01 00:09:27.7920
# 1           370  2021-02-01 00:07:08.8080  2021-02-01 00:13:19.4670
# 2           635  2021-02-01 00:07:55.9390  2021-02-01 00:18:31.0390
# 3           758  2021-02-01 00:08:42.0960  2021-02-01 00:21:20.7820
# 4           522  2021-02-01 00:09:32.6820  2021-02-01 00:18:15.4100
#
#    start station id       start station name  start station latitude  \
# 0              3175  W 70 St & Amsterdam Ave               40.777480
# 1              3154          E 77 St & 3 Ave               40.773142
# 2               502      Henry St & Grand St               40.714211
# 3              3136          5 Ave & E 63 St               40.766368
# 4               505          6 Ave & W 33 St               40.749013
#
#    start station longitude  end station id        end station name  \
# 0               -73.982886            4045  West End Ave & W 60 St
# ...

# %%
mar_df = pd.read_csv('./data/202103-citibike-tripdata.csv', low_memory=False)

# %%
mar_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1753  2021-03-01 00:00:00.1220  2021-03-01 00:29:13.1460
# 1           131  2021-03-01 00:00:00.9650  2021-03-01 00:02:12.8080
# 2          1318  2021-03-01 00:00:02.6190  2021-03-01 00:22:01.2180
# 3           199  2021-03-01 00:00:03.9060  2021-03-01 00:03:23.5870
# 4          1594  2021-03-01 00:00:06.0890  2021-03-01 00:26:40.4410
#
#    start station id              start station name  start station latitude  \
# 0              3113  Greenpoint Ave & Manhattan Ave               40.730260
# 1              2012                 E 27 St & 1 Ave               40.739445
# 2              3746               6 Ave & Broome St               40.724308
# 3               540         Lexington Ave & E 29 St               40.743116
# 4              3123             31 St & Thomson Ave               40.744697
#
#    start station longitude  end station id             end station name  \
# ...

# %%
apr_df = pd.read_csv('./data/202104-citibike-tripdata.csv', low_memory=False)

# %%
apr_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           370  2021-04-01 00:00:02.8730  2021-04-01 00:06:13.3450
# 1          2102  2021-04-01 00:00:04.7670  2021-04-01 00:35:07.2640
# 2           306  2021-04-01 00:00:05.9260  2021-04-01 00:05:12.0290
# 3           425  2021-04-01 00:00:07.5420  2021-04-01 00:07:13.4670
# 4           107  2021-04-01 00:00:16.4570  2021-04-01 00:02:04.4020
#
#    start station id             start station name  start station latitude  \
# 0              4111           E 27 St & Park Ave S               40.742752
# 1              3087  Metropolitan Ave & Meeker Ave               40.714133
# 2               465             Broadway & W 41 St               40.755136
# 3              3093           N 6 St & Bedford Ave               40.717452
# 4              3724     7 Ave & Central Park South               40.766741
#
#    start station longitude  end station id        end station name  \
# ...

# %%
df = pd.concat(map(pd.read_csv, ['./data/202101-citibike-tripdata.csv', './data/202102-citibike-tripdata.csv','./data/202103-citibike-tripdata.csv','./data/202104-citibike-tripdata.csv']))

# %%
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          2513  2021-01-01 00:00:11.9020  2021-01-01 00:42:05.2260
# 1          2519  2021-01-01 00:00:15.0960  2021-01-01 00:42:14.9780
# 2          1207  2021-01-01 00:00:28.9300  2021-01-01 00:20:36.6510
# 3          2506  2021-01-01 00:00:32.7130  2021-01-01 00:42:19.3980
# 4           959  2021-01-01 00:00:35.3650  2021-01-01 00:16:34.6010
#
#    start station id          start station name  start station latitude  \
# 0              3581  Underhill Ave & Lincoln Pl               40.674012
# 1              3581  Underhill Ave & Lincoln Pl               40.674012
# 2              3144          E 81 St & Park Ave               40.776777
# 3              3581  Underhill Ave & Lincoln Pl               40.674012
# 4               534     Water - Whitehall Plaza               40.702551
#
#    start station longitude  end station id            end station name  \
# ...

# %%
df.to_csv('combined_biking.csv', encoding='utf-8', index=False)
